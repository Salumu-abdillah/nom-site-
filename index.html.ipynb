# %%
<!DOCTYPE html>
<html lang="fr">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>Mon Portfolio</title>
  <link rel="stylesheet" href="index.CSS" />
</head>
<body>

<header>
  <h1>Mon Portfolio</h1>
  <h2>Identité</h2>
  <h2>Études faites</h2>
  <h3>Expériences</h3>
  <nav>
    <ul>
      <li><a href="#about">À propos</a></li>
      <li><a href="#projects">Projets</a></li>
      <li><a href="#contact">Contact</a></li>
    </ul>
  </nav>
</header>

<section id="about">
  <h2>À propos de moi</h2>
  <p>Je suis un développeur passionné par le web et la création d'expériences uniques.</p>
</section>

<section id="projects">
  <h2>Mes Projets</h2>

  <div class="project">
    <h3>Projet 1 : <b>Mise en forme</b></h3>
    <font color="#ff0000">Ce texte sera en rouge.</font>
    <p>Description du projet.</p>
    <h3>La Promotion de BAC3</h3>
  </div>

  <div class="project">
    <h3>Projet 2 : <b>Les images</b></h3>
    <p>Description du projet : Ajout des images.</p>
    <img src="logo-1.png" width="200" height="200" />
  </div>

  <div class="project">
    <h3>Projet 3 : <b>Les liens hypertextes</b></h3>
    <p>Description du projet.</p>
    <a href="#about">À propos</a>
    <a href="#projects">Projets</a>
    <a href="#contact">Contact</a>
  </div>

  <div class="project">
    <h3>Projet 4 : <b>Les listes</b></h3>
    <p>Les noms des présidents :</p>
    <ul>
      <li>Kasavubu</li>
      <li>Mobutu</li>
      <li>Mzee Kabila</li>
      <li>Joseph Kabila</li>
      <li>Tshisekedi</li>
    </ul>

    <p>Liste ordonnée :</p>
    <ol type="1">
      <li>Kasavubu</li>
      <li>Mobutu</li>
      <li>Mzee Kabila
        <ul>
          <li>Joseph Kabila</li>
          <li>Jeannette Kabila</li>
          <li>Zoe Kabila</li>
        </ul>
      </li>
      <li>Joseph Kabila</li>
      <li>Tshisekedi</li>
    </ol>
  </div>

  <div class="project">
    <h3>Projet 5 : <b>Les tableaux</b></h3>

    <table border="1">
      <caption>Les Cellules</caption>
      <tr><td>Cellule 1</td><td>Cellule 2</td></tr>
      <tr><td>Cellule 3</td><td>Cellule 4</td></tr>
    </table>
    <br />

    <table border="1">
      <caption>Les Pays et les villes</caption>
      <tr><th>Pays</th><th>Ville</th></tr>
      <tr><td>DRC</td><td>Kinshasa</td></tr>
      <tr><td>Corée</td><td>Séoul</td></tr>
    </table>
    <br />

    <table border="1">
      <tr>
        <td colspan="4">Cette cellule comprend 4 colonnes</td>
      </tr>
    </table>
  </div>

  <div class="project">
    <h3>Projet 6 : <b>Les formulaires</b></h3>
    <form action="envoi-formulaire.php" method="post">
      <input type="text" name="code_postal" size="5" maxlength="5" />
      <input type="text" name="nom_champ" readonly value="Champ verrouillé" />
      <input type="text" name="login" value="Entrez ici votre login" size="20" />
      <input type="password" name="mdp" />
      <br />

      <textarea name="commentaire" rows="5" cols="80"></textarea>
      <br />
      <textarea name="sujet" rows="6" cols="100">Texte par défaut</textarea>
      <br />

      <input type="hidden" name="clef" value="dfdfff3238jfHHjjeokf" />
      <br />

      <input type="file" name="image" />
      <br /><br />

      <p>Civilité :</p>
      <input type="radio" name="civilité" value="mlle" /> Mademoiselle
      <input type="radio" name="civilité" value="mme" /> Madame
      <input type="radio" name="civilité" value="mr" /> Monsieur

      <p>Genre :</p>
      <input type="radio" name="genre" value="homme" checked /> Homme
      <input type="radio" name="genre" value="femme" /> Femme
      <input type="radio" name="genre" value="et" /> Autre
      <input type="radio" name="genre" value="indéfini" /> Indéfini
      <br /><br />

      <p>Qualités :</p>
      <input type="checkbox" name="qualite[]" value="intelligent" /> Intelligent<br />
      <input type="checkbox" name="qualite[]" value="beau" /> Beau<br />
      <input type="checkbox" name="qualite[]" value="serviable" /> Serviable<br />
      <input type="checkbox" name="qualite[]" value="fort" /> Fort<br />
      <input type="checkbox" name="qualite[]" value="généreux" /> Généreux<br />

      <input type="button" name="addition" value="Additionner" onclick="addition();" />
      <button type="button" name="multiplication" onclick="multiplication();"><b>Multiplier</b></button>
      <br /><br />

      <input type="submit" name="envoyer" value="Valider" />
      <input type="reset" name="effacer" value="Effacer toutes les valeurs" />
      <button type="reset" name="effacer">Réinitialiser</button>
      <br /><br />

      <select name="couleur_yeux">
        <option value="bleus">Bleus</option>
        <option value="bruns" selected>Bruns</option>
        <option value="verts">Verts</option>
        <option value="noisettes">Noisettes</option>
        <option value="gris">Gris</option>
        <option value="vairons">Vairons</option>
      </select>
      <br /><br />

      <select name="matieres_preferees" size="5" multiple>
        <option value="maths">Maths</option>
        <option value="français">Français</option>
        <option value="anglais">Anglais</option>
        <option value="histoire">Histoire</option>
        <option value="sport">Sport</option>
        <option value="dessin">Dessin</option>
        <option value="musique">Musique</option>
        <option value="physique">Physique</option>
        <option value="sciences naturelles">Sciences naturelles</option>
      </select>
    </form>
  </div>

</section>

<section id="contact">
  <h2>Contact</h2>
  <p>
    Vous pouvez me contacter à :
    <a href="mailto:dahouda37@gmail.com">dahouda37@gmail.com</a>
  </p>
</section>

<footer>
  <p>&copy; 2025 Mon Portfolio</p>
</footer>

</body>
</html>
# Out:
#   Cell In[1], line 27
#     <p>Je suis un développeur passionné par le web et la création d'expériences uniques.</p>
#                                                                    ^
# SyntaxError: unterminated string literal (detected at line 27)
